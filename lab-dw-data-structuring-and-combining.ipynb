# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
# Import Pandas library
import pandas as pd

# %%
# Load data list from url
url1 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv'
insurance_df1 = pd.read_csv(url1)

# %%
insurance_df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
# Load data list from url
url2 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv'
insurance_df2 = pd.read_csv(url2)

# %%
insurance_df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
# Load data list from url
url3 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv'
insurance_df3 = pd.read_csv(url3)

# %%
insurance_df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
insurance_df1.columns = [column.lower() for column in insurance_df1.columns]
insurance_df2.columns = [column.lower() for column in insurance_df2.columns]
insurance_df3.columns = [column.lower() for column in insurance_df3.columns]

# %%
insurance_df1.columns = [column.replace(' ','_') for column in insurance_df1.columns]
insurance_df2.columns = [column.replace(' ','_') for column in insurance_df2.columns]
insurance_df3.columns = [column.replace(' ','_') for column in insurance_df3.columns]

# %%
insurance_df1.rename(columns={"st": "state"}, inplace=True)
insurance_df2.rename(columns={"st": "state"}, inplace=True)

# %%
insurance_df1
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
insurance_df2
# Out:
#     customer       state gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# ...

# %%
insurance_df3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
insurance_df1["number_of_open_complaints"].value_counts()
# Out:
# number_of_open_complaints
# 1/0/00    830
# 1/1/00    138
# 1/2/00     50
# 1/3/00     34
# 1/4/00     13
# 1/5/00      6
# Name: count, dtype: int64

# %%
insurance_df1["number_of_open_complaints"].unique()
# Out:
# array(['1/0/00', '1/2/00', '1/1/00', '1/3/00', '1/5/00', '1/4/00', nan],
#       dtype=object)

# %%
insurance_df1["number_of_open_complaints"]=insurance_df1["number_of_open_complaints"].fillna('1/0/00')

# %%
insurance_df1["number_of_open_complaints"].unique()
# Out:
# array(['1/0/00', '1/2/00', '1/1/00', '1/3/00', '1/5/00', '1/4/00'],
#       dtype=object)

# %%
insurance_df1["number_of_open_complaints"]=insurance_df1["number_of_open_complaints"].astype(str)

# %%
insurance_df1["number_of_open_complaints"].unique()
# Out:
# array(['1/0/00', '1/2/00', '1/1/00', '1/3/00', '1/5/00', '1/4/00'],
#       dtype=object)

# %%
insurance_df1["number_of_open_complaints"]=insurance_df1["number_of_open_complaints"].apply(lambda noc: noc.split("/")[1])

# %%
insurance_df1["number_of_open_complaints"]=insurance_df1["number_of_open_complaints"].astype(int)

# %%
insurance_df2["number_of_open_complaints"].value_counts()
# Out:
# number_of_open_complaints
# 1/0/00    796
# 1/1/00    109
# 1/2/00     43
# 1/3/00     26
# 1/4/00     16
# 1/5/00      6
# Name: count, dtype: int64

# %%
insurance_df2["number_of_open_complaints"]=insurance_df2["number_of_open_complaints"].astype(str)

# %%
insurance_df2["number_of_open_complaints"]=insurance_df2["number_of_open_complaints"].apply(lambda noc: noc.split("/")[1])

# %%
insurance_df2["number_of_open_complaints"]=insurance_df2["number_of_open_complaints"].astype(int)

# %%
insurance_df1.set_index('customer', inplace=True)
insurance_df2.set_index('customer', inplace=True)
insurance_df3.set_index('customer', inplace=True)

# %%
insurance_df_all = pd.concat([insurance_df1, insurance_df2, insurance_df3], axis=0)

# %%
insurance_df_all
# Out:
#                state gender             education customer_lifetime_value  \
# customer
# RB50392   Washington    NaN                Master                     NaN
# QZ44356      Arizona      F              Bachelor              697953.59%
# AI49188       Nevada      F              Bachelor             1288743.17%
# WW63253   California      M              Bachelor              764586.18%
# GA49547   Washington      M  High School or Below              536307.65%
# ...              ...    ...                   ...                     ...
# LA72316   California      M              Bachelor             23405.98798
# PK87824   California      F               College             3096.511217
# TD14365   California      M              Bachelor             8163.890428
# UP19263   California      M               College             7524.442436
# Y167826   California      M               College             2611.836866
#
#            income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
insurance_df_all.nunique()
# Out:
# state                           8
# gender                          5
# education                       6
# customer_lifetime_value      8211
# income                       5655
# monthly_premium_auto          209
# number_of_open_complaints       6
# policy_type                     3
# vehicle_class                   6
# total_claim_amount           5070
# dtype: int64

# %%
insurance_df_all["gender"].unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
insurance_df_all["gender"].value_counts()
# Out:
# gender
# F         4560
# M         4368
# Male        40
# female      30
# Femal       17
# Name: count, dtype: int64

# %%
# Gender column contains various inconsistent values such as "F", "M", "Femal", "Male", "female",
# which need to be standardized, for example, to "M" and "F".
insurance_df_all["gender"]=insurance_df_all["gender"].apply(lambda gen: "M" if gen=="Male" else "F" if gen=="female" else "F" if gen=="Femal" else gen)

# %%
insurance_df_all["gender"].value_counts()
# Out:
# gender
# F    4607
# M    4408
# Name: count, dtype: int64

# %%
insurance_df_all["state"].value_counts()
# Out:
# state
# California    3032
# Oregon        2601
# Arizona       1630
# Nevada         882
# Washington     768
# Cali           120
# AZ              74
# WA              30
# Name: count, dtype: int64

# %%
insurance_df_all["state"]=insurance_df_all["state"].apply(lambda st: "Washington" if st=="WA" else "Arizona" if st=="AZ" else "California" if st=="Cali" else st)

# %%
insurance_df_all["state"].value_counts()
# Out:
# state
# California    3152
# Oregon        2601
# Arizona       1704
# Nevada         882
# Washington     798
# Name: count, dtype: int64

# %%
insurance_df_all["education"].value_counts()
# Out:
# education
# Bachelor                2719
# College                 2682
# High School or Below    2616
# Master                   752
# Doctor                   344
# Bachelors                 24
# Name: count, dtype: int64

# %%
insurance_df_all["education"]=insurance_df_all["education"].apply(lambda edu: "Bachelor" if edu=="Bachelors" else edu)

# %%
insurance_df_all["education"].value_counts()
# Out:
# education
# Bachelor                2743
# College                 2682
# High School or Below    2616
# Master                   752
# Doctor                   344
# Name: count, dtype: int64

# %%
insurance_df_all["customer_lifetime_value"]=insurance_df_all["customer_lifetime_value"].apply(lambda clv: str(clv))

# %%
insurance_df_all["customer_lifetime_value"]=insurance_df_all["customer_lifetime_value"].apply(lambda clv: clv.replace("%","") if "%" in clv else clv)

# %%
insurance_df_all["customer_lifetime_value"]=insurance_df_all["customer_lifetime_value"].apply(lambda clv: float(clv))

# %%
insurance_df_all["customer_lifetime_value"].value_counts()
# Out:
# customer_lifetime_value
# 16468.220790    6
# 5246.278375     6
# 22332.439460    6
# 4270.034394     6
# 5107.163002     6
#                ..
# 7477.176362     1
# 15700.284360    1
# 2968.077571     1
# 5452.171237     1
# 2611.836866     1
# Name: count, Length: 8211, dtype: int64

# %%
insurance_df_all["vehicle_class"].value_counts()
# Out:
# vehicle_class
# Four-Door Car    4641
# Two-Door Car     1896
# SUV              1774
# Sports Car        483
# Luxury SUV        182
# Luxury Car        161
# Name: count, dtype: int64

# %%
insurance_df_all["vehicle_class"]=insurance_df_all["vehicle_class"].apply(lambda vc: "Luxury" if vc=="Sports Car" else "Luxury" if vc=="Luxury SUV" else "Luxury" if vc=="Luxury Car" else vc)

# %%
insurance_df_all["vehicle_class"].value_counts()
# Out:
# vehicle_class
# Four-Door Car    4641
# Two-Door Car     1896
# SUV              1774
# Luxury            826
# Name: count, dtype: int64

# %%
insurance_df_all.nunique()
# Out:
# state                           5
# gender                          2
# education                       5
# customer_lifetime_value      8211
# income                       5655
# monthly_premium_auto          209
# number_of_open_complaints       6
# policy_type                     3
# vehicle_class                   4
# total_claim_amount           5070
# dtype: int64

# %%
insurance_df_all["number_of_open_complaints"].unique()
# Out:
# array([0, 2, 1, 3, 5, 4], dtype=int64)

# %%
insurance_df_all["number_of_open_complaints"].value_counts()
# Out:
# number_of_open_complaints
# 0    10192
# 1     1012
# 2      376
# 3      290
# 4      148
# 5       56
# Name: count, dtype: int64

# %%
insurance_df_all.isnull().any()
# Out:
# state                         True
# gender                        True
# education                     True
# customer_lifetime_value       True
# income                        True
# monthly_premium_auto          True
# number_of_open_complaints    False
# policy_type                   True
# vehicle_class                 True
# total_claim_amount            True
# dtype: bool

# %%
insurance_df_all.isnull().sum()
# Out:
# state                        2937
# gender                       3059
# education                    2937
# customer_lifetime_value      2944
# income                       2937
# monthly_premium_auto         2937
# number_of_open_complaints       0
# policy_type                  2937
# vehicle_class                2937
# total_claim_amount           2937
# dtype: int64

# %%
insurance_df_all.dropna()
# Out:
#                state gender             education  customer_lifetime_value  \
# customer
# QZ44356      Arizona      F              Bachelor             6.979536e+05
# AI49188       Nevada      F              Bachelor             1.288743e+06
# WW63253   California      M              Bachelor             7.645862e+05
# GA49547   Washington      M  High School or Below             5.363077e+05
# OC83172       Oregon      F              Bachelor             8.256298e+05
# ...              ...    ...                   ...                      ...
# LA72316   California      M              Bachelor             2.340599e+04
# PK87824   California      F               College             3.096511e+03
# TD14365   California      M              Bachelor             8.163890e+03
# UP19263   California      M               College             7.524442e+03
# Y167826   California      M               College             2.611837e+03
#
# ...

# %%
insurance_df_all.duplicated().any()
# Out:
# True

# %%
insurance_df_all.duplicated().sum()
# Out:
# 3198

# %%
insurance_df_all.drop_duplicates(inplace=True)

# %%
insurance_df_all
# Out:
#                state gender             education  customer_lifetime_value  \
# customer
# RB50392   Washington    NaN                Master                      NaN
# QZ44356      Arizona      F              Bachelor             6.979536e+05
# AI49188       Nevada      F              Bachelor             1.288743e+06
# WW63253   California      M              Bachelor             7.645862e+05
# GA49547   Washington      M  High School or Below             5.363077e+05
# ...              ...    ...                   ...                      ...
# LA72316   California      M              Bachelor             2.340599e+04
# PK87824   California      F               College             3.096511e+03
# TD14365   California      M              Bachelor             8.163890e+03
# UP19263   California      M               College             7.524442e+03
# Y167826   California      M               College             2.611837e+03
#
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
# Load data list from url
url4 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv'
marketing_df = pd.read_csv(url4)

# %%
marketing_df
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
# Explore and analyze this data by performing data cleaning, formatting, and structuring.
marketing_df.nunique()
# Out:
# unnamed:_0                       10910
# customer                          9134
# state                                5
# customer_lifetime_value           8041
# response                             2
# coverage                             3
# education                            5
# effective_to_date                   59
# employmentstatus                     5
# gender                               2
# income                            5694
# location_code                        3
# marital_status                       3
# monthly_premium_auto               202
# months_since_last_claim             37
# months_since_policy_inception      100
# number_of_open_complaints            7
# number_of_policies                   9
# policy_type                          3
# policy                               9
# renew_offer_type                     4
# sales_channel                        4
# total_claim_amount                5106
# vehicle_class                        6
# ...

# %%
marketing_df["sales_channel"].unique()
# Out:
# array(['Agent', 'Call Center', 'Branch', 'Web'], dtype=object)

# %%
marketing_df["sales_channel"].value_counts()
# Out:
# sales_channel
# Agent          4121
# Branch         3022
# Call Center    2141
# Web            1626
# Name: count, dtype: int64

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
# I do not know which column is representing the revenues. This is not indicated or named correctly.
# Thus I cannot sum up the total revenue!
# Round the total revenue to 2 decimal points.
marketing_df["customer_lifetime_value"]=marketing_df["customer_lifetime_value"].apply(lambda x: round(x,2))

# %%
# Round the total revenue to 2 decimal points.
marketing_df["total_claim_amount"]=marketing_df["total_claim_amount"].apply(lambda x: round(x,2))

# %%
# Which sales channel brought the most sales in terms of total revenue?
# Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
pivot_marketing_df = marketing_df.pivot_table(index='customer', columns='sales_channel', values=['customer_lifetime_value', 'total_claim_amount'], aggfunc='sum')

# %%
pivot_marketing_df
# Out:
#               customer_lifetime_value                                  \
# sales_channel                   Agent    Branch Call Center       Web
# customer
# AA10041                           NaN       NaN    23705.22       NaN
# AA11235                           NaN   5137.68         NaN       NaN
# AA16582                      24127.50       NaN         NaN       NaN
# AA30683                           NaN       NaN         NaN   6595.10
# AA34092                           NaN       NaN         NaN  28799.95
# ...                               ...       ...         ...       ...
# ZZ77357                       4468.22       NaN         NaN       NaN
# ZZ83340                           NaN   5508.32         NaN       NaN
# ZZ89380                           NaN       NaN     3196.58       NaN
# ZZ91716                           NaN       NaN         NaN   6513.54
# ZZ97035                           NaN  20714.94         NaN       NaN
#
#               total_claim_amount
# ...

# %%
# Analyze the resulting table to draw insights.
# I do not know which column is representing the revenues. This is not indicated or named correctly.
# Thus I cannot sum up the total revenue!

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
pivot_marketing_df2 = marketing_df.pivot_table(index='gender', columns='education', values=['customer_lifetime_value'], aggfunc='mean')

# %%
pivot_marketing_df2
# Out:
#           customer_lifetime_value                            \
# education                Bachelor      College       Doctor
# gender
# F                     7874.269547  7748.823526  7328.508650
# M                     7703.601609  8052.459430  7415.333532
#
#
# education High School or Below       Master
# gender
# F                  8675.220038  8157.053137
# M                  8149.687629  8168.832670

# %%
# Analyze the resulting table to draw insights.

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
